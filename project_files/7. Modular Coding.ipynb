# %% [markdown]
# - While Jupyter Notebooks are commonly used for model building and experimentation, transitioning to a production environment requires additional steps. To achieve a production-grade setup, we need to:
#
# - Modularize the Code: Refactor the notebook code into modular, reusable components. This includes separating data processing, feature engineering, model building, and utility functions into distinct modules.
#
# - Implement CI/CD Pipelines: Establish Continuous Integration (CI) and Continuous Deployment (CD) pipelines to automate testing, integration, and deployment. This ensures that the code is regularly tested and deployed in a consistent and reliable manner.
#
# - Ensure Continuous Operation: Set up the system so that it runs continuously and can handle production workloads effectively. This involves monitoring, logging, and maintaining the system to ensure its reliability and performance.
#
# By following these steps, we can ensure that our model transitions smoothly from development in Jupyter Notebooks to a robust production environment.

# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# - As a data scientist, we'll be working in a team, where big-data team will gather data from multiple sources & store in dbs or cloud or via api etc & we need to extract from there & move forward
#
# - read data, split into train test & then perform transformation
# - write code under src/components/data_igestion.py
# - after you run the code, you will see logs folder will have a new file:
#
# ![image.png](attachment:image.png)
# - also, a new folder 'artifacts' with new files:
#
# ![image-2.png](attachment:image-2.png)
# - add artifacts folder to .gitignore file
# - commit & push data to git repo

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# - write code for all the transformations on numerical & categorical cols seperately
# - add both in pipelines & create preprocessor pkl file
# - run data_transformation which will ingest the data, train test split & apply transformations & create pkl file
# - check logs & file getting created
# - At the end, push the files to git repo

# %% [markdown]
# ## Model Training  & Evaluating

# %%
#we'll train multiple algorithms & pick the 1 which performs better
#also we have applied hyper parameter tuning using gridsearchcv

# %% [markdown]
# ## Flask App deployment
